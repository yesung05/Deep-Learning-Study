# %% [markdown]
# <a href="https://colab.research.google.com/github/yesung05/Deep-Learning-Study/blob/main/w04_4_nparray_calculate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SECTION 4 배열 연산

# %% [markdown]
# ## 배열과 스칼라의 연산

# %%
import numpy as np

a = np.arange(3)
a
# Out:
# array([0, 1, 2])

# %%
print(a+2) #모든 값에 2씩 더하기
print(a-2) #모든 값에 2씩 빼기
print(a*2) #모든 값을 2로 곱하기
print(a/2) #모든 값을 2로 나누기
# Out:
# [2 3 4]
# [-2 -1  0]
# [0 2 4]
# [0.  0.5 1. ]

# %%
a = np.arange(1,7).reshape(2,3)
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b = np.full_like(a,[1,2,3]) # a 와 같은 배열구조에 1,2,3 이 들어간 배열 생성

# %%
print(a+b) #1+1 2+2 3+3 4+1 5+2 6+3 등등
print(a-b)
print(a*b)
print(a/b)
# Out:
# [[2 4 6]
#  [5 7 9]]
# [[0 0 0]
#  [3 3 3]]
# [[ 1  4  9]
#  [ 4 10 18]]
# [[1.  1.  1. ]
#  [4.  2.5 2. ]]

# %%
a= np.arange(4)
a
# Out:
# array([0, 1, 2, 3])

# %%
b = np.arange(0.5, 4, 1)
b
# Out:
# array([0.5, 1.5, 2.5, 3.5])

# %%
a += b #a는 int 형인데 int형+실수 더해서 나온 실수 결과를 a 에 넣을려 해서 오류 발생
# 근데 a 왜 int지 햇갈리게..
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-25-53486acfe4f7> in <cell line: 1>()
# ----> 1 a += b #a는 int 형인데 int형+실수 더해서 나온 실수 결과를 a 에 넣을려 해서 오류 발생
#       2 # 근데 a 왜 int지 햇갈리게..
#       3 b+=a
#
# UFuncTypeError: Cannot cast ufunc 'add' output from dtype('float64') to dtype('int64') with casting rule 'same_kind'

# %%
b+=a #실수는 정수를 담을 수 있음
b
# Out:
# array([0.5, 3.5, 6.5, 9.5])

# %%
a = np.full((2,3),[1,2,3])
a #a의 열과 b의 행이 같아야 함
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])

# %%
b = np.full((3,2),[2,1])
b
# Out:
# array([[2, 1],
#        [2, 1],
#        [2, 1]])

# %%
a @ b
# Out:
# array([[12,  6],
#        [12,  6]])

# %%
a.dot(b) #같은거
# Out:
# array([[12,  6],
#        [12,  6]])

# %%
b.dot(a) #반대로 되는 이유는 a와 b의 행과 열, 열과 행이 서로 같기떄문
# Out:
# array([[3, 6, 9],
#        [3, 6, 9],
#        [3, 6, 9]])

# %% [markdown]
# ## 배열 함수

# %%
a = np.array([[10,20],[5,6],[1,2]]) #2차원
a
# Out:
# array([[10, 20],
#        [ 5,  6],
#        [ 1,  2]])

# %%
a.sum()
# Out:
# 44

# %%
a.sum(axis=0) #0은 세로끼리 1은 가로끼리
# Out:
# array([16, 28])

# %%
a.sum(axis=1)
# Out:
# array([30, 11,  3])

# %%
import numpy as np
#sum 자체는 기본으로 있는데 np.sum은 기능이 다른가?
print(np.sum(a))
print(np.sum(a, axis=0))
print(np.sum(a, axis=1))
# Out:
# 44
# [16 28]
# [30 11  3]

# %%
## 중간고사 시험!!!! ! ! !! ! !
a = np.array([[3,5,7],[1,2,3]])
a
# Out:
# array([[3, 5, 7],
#        [1, 2, 3]])

# %%
a.cumsum() #배열의 값을 지속적으로 더함
# Out:
# array([ 3,  8, 15, 16, 18, 21])

# %%
a.cumsum(axis=0)
# Out:
# array([[ 3,  5,  7],
#        [ 4,  7, 10]])

# %%
a.cumsum(axis=1)
# Out:
# array([[ 3,  8, 15],
#        [ 1,  3,  6]])

# %% [markdown]
# ## 범용 함수

# %%
import numpy as np
a = np.array([1,4,9])
np.sqrt(a) #제곱해서 n이 되는 것
# Out:
# array([1., 2., 3.])

# %%
np.log(a)
# Out:
# array([0.        , 1.38629436, 2.19722458])

# %%
import numpy as np

a = np.array([1,4,9])
a
# Out:
# array([1, 4, 9])

# %%
b = np.full_like(a,2)
b
# Out:
# array([2, 2, 2])

# %%
np.add(a,b)
# Out:
# array([ 3,  6, 11])

# %%
np.divide(a,b)
# Out:
# array([0.5, 2. , 4.5])

# %%
np.power(a,b)
# Out:
# array([ 1, 16, 81])
